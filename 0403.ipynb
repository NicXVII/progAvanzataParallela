// %% [markdown]
// Sequenza di compilazione
//  assembly
//
//  Compilazione: check del output
//
//
//  Ottimizzazioni: viene generato
//     molte automatiche (viene scritto comando al compilatore)
//         esempi:
//                 propagazione delle costanti: se possibile computare valore drnte complazione posso inserire il risultato
//
//     loop unrolling:
//                     per cicli con un piccolo numero
//                     abilitata con funroll loops e disabilitata con fno unroll loops
//
//     funtion inlinign: sostituisce una chiamata a funzione col corpo della funzione
//                         eviti di fare chiamata a funzione, svanaggio
//
//
//     linkless branch: possiamo indicare se un branch prob venga preso/ no

// %% [markdown]
// perche servono cache
//     se accesi solo registri stesso codice 20 piu veloce
//     pochi registri
//     impossibile rendere memoria iu veloce
//
// dmensioni cache
//     tradeoffs
//         rapp lentezza grandezza -- di solito diversi livelli con diversi tradeoof tra dim e prest
//     l1dati l1 istruzioni
//         due ache separate per dati e istruzioni
//     l2
//         non distingue dati istruzioni,spec dimensioni per core
//     l3
//         +grande lenta l2, spesso condivisa tra core
//
//
//
// come accedo
//     non carica mai 1 byte alla volta
//     carica intera cache line
//     dim spesso 64 bytes
//
//
// disposizione in memoria:
//     struct pessima dispo memoria: primo acc copiamo valore nella cache line, puntatore gia nella cache nel accesso, prox nodo potr -cache line
//
// allineamento (a memoria specrata)
//     molte strutture pos richiedere p+ bytes della somma bytes occupanti
//     load o equivalent accedere indirizzi multipli 4/8 bytes
//     standard compilatore rispetta ordini membri strutture
//     padding byte vuoti messi
//     accedere modo allineato
//
// array di stutture
//     pattern comune avre insime strutture e fare oparazione comune in membro
