# %% [markdown]
# array np vs liste python
#  prestazioni: numpy piu compatti, + veloci quando svolgo stessa op su tutti elementi, - se usati liste, + lavorano dati omogenei

# %% [markdown]
# operazioni: clipping(min,max) = tutti i valori nel intervallo
